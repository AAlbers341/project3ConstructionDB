# %%
import pandas as pd

# %%
estimateitems_df = pd.read_csv('../../data/raw/estimateitems.csv')
pd.set_option('display.max_columns', None)
estimateitems_df
# Out:
#     EstimateItemID  EstimateID  ItemID     Page  AccessoryItemID  PartNumber  \
# 0          6831964        5409     100    BEAMS              NaN         NaN
# 1          6832047        5409     200    BEAMS              NaN         NaN
# 2          6832049        5409     300    BEAMS              NaN         NaN
# 3          6899499        5409     400    BEAMS              NaN         NaN
# 4          6906767        5409     500    BEAMS              NaN         NaN
# 5          6831872        5409     100  COLUMNS              NaN         NaN
# 6          6899482        5409     900  COLUMNS              NaN         NaN
# 7          6899483        5409    1000  COLUMNS              NaN         NaN
# 8          6899835        5409    1050  COLUMNS              NaN         NaN
# 9          6899484        5409    1100  COLUMNS              NaN         NaN
# 10         6899485        5409    1200  COLUMNS              NaN         NaN
# ...

# %%
estimateitems_df.columns
# Out:
# Index(['EstimateItemID', 'EstimateID', 'ItemID', 'Page', 'AccessoryItemID',
#        'PartNumber', 'DimensionString', 'DimensionStringMetric', 'ManHours',
#        'CalculatedManHours', 'ManualOverrideSum', 'CalculatedHash', 'Weight',
#        'WeightItem', 'WeightWeld', 'SurfaceArea', 'SquareMetersEach',
#        'Perimeter', 'MaterialCostPricingTypeID', 'MaterialCostCurrencyID',
#        'MaterialUnitCost', 'MaterialCost', 'MaterialDropCost',
#        'MaterialDropWeight', 'MaterialCostUnits', 'MaterialCostDate',
#        'ShopBolts', 'FieldBolts', 'Quantity', 'ShapeID', 'SizeID', 'DimDepth',
#        'DimWidth', 'DimWeight', 'DimThickness', 'DimGage', 'DimDiameter',
#        'DimComment', 'Length', 'GradeID', 'Camber', 'EstimateExtraString',
#        'LaborCodeID', 'Copes', 'Holes', 'HolesWithoutBolts', 'Stiffeners',
#        'TopFlangeHoles', 'WebHoles', 'BottomFlangeHoles', 'WeldedStuds',
#        'ManHoursPerPiece', 'CostPerPieceCurrencyID', 'CostPerPiece',
# ...

# %%
estimateitems_df = estimateitems_df.drop(['SquareMetersEach'], axis=1)
estimateitems_df.columns
# Out:
# Index(['EstimateItemID', 'EstimateID', 'ItemID', 'Page', 'AccessoryItemID',
#        'PartNumber', 'DimensionString', 'DimensionStringMetric', 'ManHours',
#        'CalculatedManHours', 'ManualOverrideSum', 'CalculatedHash', 'Weight',
#        'WeightItem', 'WeightWeld', 'SurfaceArea', 'Perimeter',
#        'MaterialCostPricingTypeID', 'MaterialCostCurrencyID',
#        'MaterialUnitCost', 'MaterialCost', 'MaterialDropCost',
#        'MaterialDropWeight', 'MaterialCostUnits', 'MaterialCostDate',
#        'ShopBolts', 'FieldBolts', 'Quantity', 'ShapeID', 'SizeID', 'DimDepth',
#        'DimWidth', 'DimWeight', 'DimThickness', 'DimGage', 'DimDiameter',
#        'DimComment', 'Length', 'GradeID', 'Camber', 'EstimateExtraString',
#        'LaborCodeID', 'Copes', 'Holes', 'HolesWithoutBolts', 'Stiffeners',
#        'TopFlangeHoles', 'WebHoles', 'BottomFlangeHoles', 'WeldedStuds',
#        'ManHoursPerPiece', 'CostPerPieceCurrencyID', 'CostPerPiece',
# ...

# %%
estimateitems_df.to_csv('../../data/cleaned/estimateitems.csv', index=False)
