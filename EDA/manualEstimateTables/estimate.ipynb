# %%
import pandas as pd

# %%
estimates_df = pd.read_csv('../../data/estimates.csv')
pd.set_option('display.max_columns', None)
estimates_df
# Out:
#    EstimateID       Estimator     BidDate   JobNumber  \
# 0        5409  Scott DeSomber  2024-02-22  EPM24-0126
#
#                            JobName  Location  JobStatusID  Other1  Other2  \
# 0  23-838 Ag Line 40' Hand Takeoff       NaN            1     NaN     NaN
#
#    DistanceToJob  ShopDrawingCostCurrencyID  ShopDrawingCost  \
# 0            0.0                          1              0.0
#
#    ShopDrawingHours  ShopEfficiency  ShopSetupID  AnglePricingTypeID  \
# 0               0.0           100.0            6                   1
#
#    BeamPricingTypeID  PlatePricingTypeID  RodPricingTypeID  TubePricingTypeID  \
# 0                  1                   1                 1                  1
#
#    OtherMaterialPricingTypeID  PricingCombinationRunID  LaborArchiveDateTime  \
# 0                           1                    52290                   NaN
#
#    LaborArchiveID  HistoricPricingDateTime  CleaningTypeID  \
# 0             NaN                      NaN               1
#
#    GalvanizingCostPerKilogramCurrencyID  GalvanizingCostPerKilogram  \
# 0                                     1                    0.771618
#
#    GalvanizingMinimumCostCurrencyID  GalvanizingMinimumCost  \
# 0                                 1                     0.0
#
#    GalvanizingTruckWeight  GalvanizingFreightCostCurrencyID  \
# 0              8618.25503                                 1
#
#    GalvanizingFreightCost  GalvanizingLaborCostCurrencyID  \
# 0                   622.0                               1
#
#    GalvanizingLaborCost  GalvanizingWeightPercent  LengthInputTypeIDImperial  \
# 0                   2.0                       6.0                          2
#
#    LengthInputTypeIDMetric  ThicknessInputTypeIDImperial  \
# 0                      101                             3
#
#    ThicknessInputTypeIDMetric DefaultFinish  DefaultPaintSystemID  \
# 0                         101           PNT                     7
#
#    DefaultCleanSystemID  ItemIncrement InputDisplayUnitsSize  \
# 0                   NaN            100              Imperial
#
#   InputDisplayUnitsLength InputDisplayUnitsWeight InputDisplayUnitsPrice  \
# 0                Imperial                Imperial               Imperial
#
#    AutoClipAngles  UseGradeSubstitutions  ApplyKerfMult  ApplyKerfNest  \
# 0               1                      0              1              1
#
#    CombiningRotatePlates  CombiningAllowSplitTees  NestingShearCut GroupName  \
# 0                      1                        1                0   HME use
#
#   GroupName2  ClientFirmID  ClientShipToFirmAddressID  \
# 0    Testing           NaN                        NaN
#
#    ClientBillToFirmAddressID  ClientFirmContactID  ProjectID  \
# 0                        NaN                  NaN        NaN
#
#    ExternalProjectID  ERPJobNumber  NumberOfItems  TotalQuantity  \
# 0                NaN           NaN             15             88
#
#     TotalLength  TotalWeight  TotalSurfaceArea  TotalSquareMeters  \
# 0  30988.061976   526.167554         20.543261           0.891292
#
#    TotalManHours  UpdateCount  ProductionCodeUpdateCount  Recalculate  \
# 0      22.230026          NaN                          0            0
#
#    RecalculateProductionCodeSummary  RecalculateEstimateSummary  \
# 0                               NaN                         NaN
#
#    EstimateSummaryUpdateCount
# 0                           1

# %%
estimates_df.columns
# Out:
# Index(['EstimateID', 'Estimator', 'BidDate', 'JobNumber', 'JobName',
#        'Location', 'JobStatusID', 'Other1', 'Other2', 'DistanceToJob',
#        'ShopDrawingCostCurrencyID', 'ShopDrawingCost', 'ShopDrawingHours',
#        'ShopEfficiency', 'ShopSetupID', 'AnglePricingTypeID',
#        'BeamPricingTypeID', 'PlatePricingTypeID', 'RodPricingTypeID',
#        'TubePricingTypeID', 'OtherMaterialPricingTypeID',
#        'PricingCombinationRunID', 'LaborArchiveDateTime', 'LaborArchiveID',
#        'HistoricPricingDateTime', 'CleaningTypeID',
#        'GalvanizingCostPerKilogramCurrencyID', 'GalvanizingCostPerKilogram',
#        'GalvanizingMinimumCostCurrencyID', 'GalvanizingMinimumCost',
#        'GalvanizingTruckWeight', 'GalvanizingFreightCostCurrencyID',
#        'GalvanizingFreightCost', 'GalvanizingLaborCostCurrencyID',
#        'GalvanizingLaborCost', 'GalvanizingWeightPercent',
#        'LengthInputTypeIDImperial', 'LengthInputTypeIDMetric',
#        'ThicknessInputTypeIDImperial', 'ThicknessInputTypeIDMetric',
#        'DefaultFinish', 'DefaultPaintSystemID', 'DefaultCleanSystemID',
#        'ItemIncrement', 'InputDisplayUnitsSize', 'InputDisplayUnitsLength',
#        'InputDisplayUnitsWeight', 'InputDisplayUnitsPrice', 'AutoClipAngles',
#        'UseGradeSubstitutions', 'ApplyKerfMult', 'ApplyKerfNest',
#        'CombiningRotatePlates', 'CombiningAllowSplitTees', 'NestingShearCut',
#        'GroupName', 'GroupName2', 'ClientFirmID', 'ClientShipToFirmAddressID',
#        'ClientBillToFirmAddressID', 'ClientFirmContactID', 'ProjectID',
#        'ExternalProjectID', 'ERPJobNumber', 'NumberOfItems', 'TotalQuantity',
#        'TotalLength', 'TotalWeight', 'TotalSurfaceArea', 'TotalSquareMeters',
#        'TotalManHours', 'UpdateCount', 'ProductionCodeUpdateCount',
#        'Recalculate', 'RecalculateProductionCodeSummary',
#        'RecalculateEstimateSummary', 'EstimateSummaryUpdateCount'],
#       dtype='object')
