# %%
import pandas as pd

# %%
grades_df = pd.read_csv('../../data/grades.csv')
grades_df
# Out:
#      GradeID  ShapeID            Grade  DefaultGrade  WeightMultiplier  \
# 0          1        3             A992             1               1.0
# 1          4        8             A307             0               1.0
# 2          8        9             A992             1               1.0
# 3         16       38              A36             0               1.0
# 4         20       44              A36             1               1.0
# ..       ...      ...              ...           ...               ...
# 502     1009       57            C1035             0               1.0
# 503     1010      264    GR.33 PREGALV             0               1.0
# 504     1011      130  STEEL_UNDEFINED             0               1.0
# 505     1012       78             ZINC             0               1.0
# 506     1013      187       ROOF SCREW             0               1.0
#
#      ProNestDesignation
# 0                   NaN
# 1                   NaN
# 2                   NaN
# ...
