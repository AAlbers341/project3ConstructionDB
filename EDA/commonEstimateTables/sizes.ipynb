# %%
import pandas as pd

# %%
sizes_df = pd.read_csv('../../data/sizes.csv')
sizes_df
# Out:
#       SizeID  ShapeID     DimDepth  DimDepthImperial  DimDepthMetric  \
# 0          1        9  1117.602235       1117.602235     1100.000000
# 1          2        9  1117.602235       1117.602235     1100.000000
# 2          3        9  1117.602235       1117.602235     1100.000000
# 3          4        9  1117.602235       1117.602235     1100.000000
# 4          5        9  1016.002032       1016.002032     1000.000000
# ...      ...      ...          ...               ...             ...
# 4191    7299      100    69.850140         69.850140       69.850140
# 4192    7300      100   304.800610        304.800610      304.800610
# 4193    7302       97          NaN               NaN             NaN
# 4194    7303      264          NaN               NaN             NaN
# 4195    7304       78    50.800102         50.800102       50.800102
#
#         DimWidth  DimWidthImperial  DimWidthMetric      DimWeight  \
# 0            NaN               NaN             NaN  498533.924026
# ...

# %% [markdown]
# Clean
# - Metric
