# %%
import pandas as pd

# %%
laborrates_df = pd.read_csv('../../data/raw/laborrates.csv')
laborrates_df
# Out:
#     LaborRateID                     Description  LaborRateCurrencyID  \
# 0             1                      Shop Labor                    1
# 1             2                       Detailing                    1
# 2             3                        Erecting                    1
# 3             4                        Checking                    1
# 4             5                        VS Blast                    1
# 5             7            Voortman System Cost                    1
# 6             8             Fabrication Welding                    1
# 7             9               Loading - Inbound                    1
# 8            12                  VS Saw & Drill                    1
# 9            13                         VS Cope                    1
# 10           19  Material Handling - Structural                    1
# 11           21                Plate Processing                    1
# 12           22                     Paint Labor                    1
# ...

# %%
laborrates_df.to_csv('../../data/cleaned/laborrates.csv', index=False)
