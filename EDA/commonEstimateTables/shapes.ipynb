# %%
import pandas as pd

# %%
shapes_df = pd.read_csv('../../data/raw/shapes.csv')
shapes_df
# Out:
#     ShapeID   Shape          Description  DimensionTabIndex  PriceFormat  \
# 0         2      EM       Expanded Metal                 15          600
# 1         3      WT     Wide Flange Tees                  0          100
# 2         4      WS  Concrete Weld Studs                  7          300
# 3         8     WSH              Washers                  4          300
# 4         9       W    Wide Flange Beams                  0          100
# ..      ...     ...                  ...                ...          ...
# 93      254    BYHW      Buyout Hardware                 32          300
# 94      256  FLANGE              Flanges                 22          300
# 95      257      WE      Weld Bend Elbow                 22          300
# 96      262     UST             Unistrut                 32          100
# 97      264      US             Unistrut                 30          200
#
#     PriceFormatDisplay  WeightFormat  SurfaceAreaFormat  PropertyFormat  \
# ...

# %%
shapes_df.to_csv('../../data/cleaned/shapes.csv', index=False)
