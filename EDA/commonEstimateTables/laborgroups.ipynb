# %%
import pandas as pd

# %%
laborgroups_df = pd.read_csv('../../data/laborgroups.csv')
laborgroups_df
# Out:
#     LaborGroupID  Number                           Description  LaborRateID  \
# 0              1      12                     Inbound Unloading            9
# 1              2       2                     Material Handling           19
# 2              3       3                         Saw Cut Labor           35
# 3              9       1                               Welding            8
# 4             11      27                              VS Blast            5
# 5             13       7                           Paint Labor           22
# 6             18      66                  Voortman System Cost            7
# 7             20       9                        VS Saw & Drill           12
# 8             22      28                         VS Coper Burn           13
# 9             27       6                      Plate Processing           21
# 10            29       8                           Fabrication            8
# ...
